# %%
import os
import cv2


labels_path = 'banco2/Nelore2/EGG/label_studio'
img_path = 'banco2/Nelore2/EGG/imgs'
label_destiny = 'banco2/Nelore2/EGG/labels'


lista_labels = sorted(os.listdir(labels_path))
lista_img    = sorted(os.listdir(img_path))
idx = 0
print(lista_labels)
print(lista_img)
for i in range(len(lista_img)):
    if 2*i +1 > 110: # aqui muda para a quantidade de imagens no label
        break
    cm1 =  os.path.join(labels_path, lista_labels[2*i] )
    cm2 = os.path.join(labels_path, lista_labels[2*i+1])
    
    img1 = cv2.imread(cm1)
    img2 = cv2.imread(cm2)

    nome, ext = os.path.splitext(lista_img[i])
    nome1 = f'{nome}_BF.jpg'
    nome2 = f'{nome}_GM.jpg'

    save1 = os.path.join(label_destiny, nome1)
    save2 = os.path.join(label_destiny, nome2)

    cv2.imwrite(save1, img1)
    cv2.imwrite(save2, img2)
# Out:
# ['task-468-annotation-301-by-1-tag-Biceps_femoris-0.png', 'task-468-annotation-301-by-1-tag-Gluteus_medius-0.png', 'task-469-annotation-302-by-1-tag-Biceps_femoris-0.png', 'task-469-annotation-302-by-1-tag-Gluteus_medius-0.png', 'task-470-annotation-303-by-1-tag-Biceps_femoris-0.png', 'task-470-annotation-303-by-1-tag-Gluteus_medius-0.png', 'task-471-annotation-304-by-1-tag-Biceps_femoris-0.png', 'task-471-annotation-304-by-1-tag-Gluteus_medius-0.png', 'task-472-annotation-305-by-1-tag-Biceps_femoris-0.png', 'task-472-annotation-305-by-1-tag-Gluteus_medius-0.png', 'task-473-annotation-306-by-1-tag-Biceps_femoris-0.png', 'task-473-annotation-306-by-1-tag-Gluteus_medius-0.png', 'task-474-annotation-307-by-1-tag-Biceps_femoris-0.png', 'task-474-annotation-307-by-1-tag-Gluteus_medius-0.png', 'task-475-annotation-308-by-1-tag-Biceps_femoris-0.png', 'task-475-annotation-308-by-1-tag-Gluteus_medius-0.png', 'task-476-annotation-309-by-1-tag-Biceps_femoris-0.png', 'task-476-annotation-309-by-
# ...
