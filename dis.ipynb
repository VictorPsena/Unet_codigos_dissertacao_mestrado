# %%
from funcs import banco, modificacoes1
import os
from PIL import Image
import matplotlib.pyplot as plt
path_in = 'banco2/teste/dissertacao'
path_out= 'banco2/teste/dissertacao2'

lista_imgs, nomes = banco(path_in, resolution=(256,256), grayscale=True, nomes=True)
img_modificadas, xtrin = modificacoes1(
    lista_imgs,
    nomes,
    original=True,
    brilho=1.7,
    escura=0.5,
    rotacao=[-15,15],
)

# %%
plt.imshow(xtrin[3], cmap='gray')
